# %%
from alcdef_util import *

# %%
file = 'ALCDEF_16_Psyche_20180207_185754.txt'
datadir = 'data'
metadata, lc = read_alcdef(file, datadir)
plot_lightcurve(metadata, lc, file)
# Out:
# ALCDEF_16_Psyche_20180207_185754 block 0: (midpoint 2015-11-30, 09:44:00)
# Observed in C, reporting V
# Reported differential magnitudes
# Times are light time corrected by -0.009812 (AVERAGE)
# ALCDEF_16_Psyche_20180207_185754 block 1: (midpoint 2015-12-01, 09:02:00)
# Observed in C, reporting V
# Reported differential magnitudes
# Times are light time corrected by -0.009806 (AVERAGE)
# ALCDEF_16_Psyche_20180207_185754 block 2: (midpoint 2015-12-26, 06:16:00)
# Observed in V, reporting V
# Reported differential magnitudes
# Times are light time corrected by -0.010166 (AVERAGE)

# %%
file = 'ALCDEF_433_Eros_20180207_185754.txt'
datadir = 'data'
metadata, lc = read_alcdef(file, datadir)
plot_lightcurve(metadata, lc, file)
# Out:
# ALCDEF_433_Eros_20180207_185754 block 0: (midpoint 2009-06-18, 10:15:00)
# Observed in CLEAR, reporting SR
# Reported differential magnitudes
# ALCDEF_433_Eros_20180207_185754 block 1: (midpoint 2009-06-19, 10:50:00)
# Observed in CLEAR, reporting SR
# Reported differential magnitudes
# ALCDEF_433_Eros_20180207_185754 block 2: (midpoint 2009-06-22, 10:10:00)
# Observed in CLEAR, reporting SR
# Reported differential magnitudes
# ALCDEF_433_Eros_20180207_185754 block 3: (midpoint 2009-10-10, 04:00:00)
# Observed in CLEAR, reporting SR
# Reported differential magnitudes
# ALCDEF_433_Eros_20180207_185754 block 4: (midpoint 2009-10-11, 04:20:00)
# Observed in CLEAR, reporting SR
# Reported differential magnitudes
# ALCDEF_433_Eros_20180207_185754 block 5: (midpoint 2009-10-18, 04:50:00)
# Observed in CLEAR, reporting SR
# Reported differential magnitudes
# ALCDEF_433_Eros_20180207_185754 block 6: (midpoint 2009-10-20, 03:15:00)
# Observed in CLEAR, reporting SR
# ...

# %%
file = 'ALCDEF_9948_1990QB2_20180207_185754.txt'
datadir = 'data'
metadata, lc = read_alcdef(file, datadir)
plot_lightcurve(metadata, lc, file)
# Out:
# ALCDEF_9948_1990QB2_20180207_185754 block 0: (midpoint 2005-11-09, 00:38:51)
# Observed in C, reporting R
# Reported differential magnitudes
# ALCDEF_9948_1990QB2_20180207_185754 block 1: (midpoint 2005-11-09, 12:18:35)
# Observed in C, reporting R
# Reported differential magnitudes
# ALCDEF_9948_1990QB2_20180207_185754 block 2: (midpoint 2005-11-11, 13:34:40)
# Observed in C, reporting R
# Reported differential magnitudes
# ALCDEF_9948_1990QB2_20180207_185754 block 3: (midpoint 2005-11-12, 13:30:32)
# Observed in C, reporting R
# Reported differential magnitudes
# ALCDEF_9948_1990QB2_20180207_185754 block 4: (midpoint 2013-12-14, 09:12:24)
# Observed in R, reporting R
# Reported differential magnitudes
# ALCDEF_9948_1990QB2_20180207_185754 block 5: (midpoint 2014-01-06, 08:18:43)
# Observed in R, reporting R
# Reported differential magnitudes
# ALCDEF_9948_1990QB2_20180207_185754 block 6: (midpoint 2014-01-07, 08:36:54)
# Observed in R, reporting R
# ...

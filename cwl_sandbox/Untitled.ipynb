# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import corner
import pandas as pd
import numpy as np

# %%
data = np.loadtxt("../data/simulation_results_new/221/221_lc_49627_to_49787.txt_sampled_ztf-lsst_60days.txtresults_1e+05.txt")

# %%
data.shape
# Out:
# (5, 5)

# %%
data = np.append(data, np.ones(len(data)), axis=0)
#data.reshape(70,5)
data
# Out:
# array([10.44028863, 11.06030474,  0.11382918, ...,  1.        ,
#         1.        ,  1.        ])

# %%
figure = corner.corner(data, labels=["period", 'gamma', 'amp', 'mean', 'loglike'])
# Out:
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours

# %%
data #add another column
# Out:
# array([[10.44028863, 11.06030474,  0.11382918,  0.76000205],
#        [10.43968063, 12.42741678,  0.0973327 ,  0.72533818],
#        [10.44016985, 15.65637989,  0.05437652,  1.15379163],
#        [10.44039144, 15.56975227,  0.0506446 ,  0.78569731],
#        [10.43985159, 14.98358155,  0.05028239,  0.72190401],
#        [10.44062003, 12.22605064,  0.03132045,  0.78988538],
#        [10.43961227, 13.31280587,  0.0643097 ,  0.88355174],
#        [10.44010391, 16.51281979,  0.04794917,  1.0700637 ],
#        [10.43958875, 10.90397581,  0.09073145,  1.14764789],
#        [10.43983012, 10.16061681,  0.13553138,  0.91251549],
#        [10.44006578, 14.3069044 ,  0.09119193,  0.87611838],
#        [10.4396932 , 10.49682727,  0.05382217,  1.24457362],
#        [10.4402462 , 11.9652275 ,  0.09471287,  0.68552048],
#        [10.44014741, 13.58193053,  0.0662228 ,  1.21091359],
#        [10.44020457, 12.06245605,  0.06218757,  0.63510464],
# ...

# %%
import datetime
now = datetime.datetime.now().strftime("%Y-%m-%d-%Hh%Mm")

now
# Out:
# '2019-06-05-14h35m'

# %%
now
# Out:
# '2019-06-05-14h35m'

# %%
filename = "test"
nsamples = 100000

# %%
np.savetxt(filename + "results_%.0e_%s.txtss" %(nsamples, now), data)

# %%
filename = "test"

f = open(filename + "_results.txt", "w+")

f.write(str(data.)

f.close()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-45-ee9e43012436> in <module>()
#       3 f = open(filename + "_results.txt", "w+")
#       4
# ----> 5 f.write(data)
#       6
#       7 f.close()
#
# TypeError: write() argument must be str, not numpy.ndarray

# %%
nsamples = 100000000

# %%
print("{:e}".format(nsamples))
# Out:
# 1.000000e+08

# %%
print("results_%.0e" %nsamples)
# Out:
# results_1e+08

# %%
np.savetxt(filename + "_results_" + .txt", data)

# %%
files = np.loadtxt(filename+"_results_%.0e.txt" %nsamples)

# %%
filename+"_results_%.0e.txt" %nsamples
# Out:
# 'test_results_1e+08.txt'

# %%
files
# Out:
# array([[10.44028863, 11.06030474,  0.11382918,  0.76000205],
#        [10.43968063, 12.42741678,  0.0973327 ,  0.72533818],
#        [10.44016985, 15.65637989,  0.05437652,  1.15379163],
#        [10.44039144, 15.56975227,  0.0506446 ,  0.78569731],
#        [10.43985159, 14.98358155,  0.05028239,  0.72190401],
#        [10.44062003, 12.22605064,  0.03132045,  0.78988538],
#        [10.43961227, 13.31280587,  0.0643097 ,  0.88355174],
#        [10.44010391, 16.51281979,  0.04794917,  1.0700637 ],
#        [10.43958875, 10.90397581,  0.09073145,  1.14764789],
#        [10.43983012, 10.16061681,  0.13553138,  0.91251549],
#        [10.44006578, 14.3069044 ,  0.09119193,  0.87611838],
#        [10.4396932 , 10.49682727,  0.05382217,  1.24457362],
#        [10.4402462 , 11.9652275 ,  0.09471287,  0.68552048],
#        [10.44014741, 13.58193053,  0.0662228 ,  1.21091359],
#        [10.44020457, 12.06245605,  0.06218757,  0.63510464],
# ...
